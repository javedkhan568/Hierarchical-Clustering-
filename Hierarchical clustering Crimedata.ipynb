# %% [markdown]
# Perform Clustering(Hierarchical, Kmeans & DBSCAN) for the crime data and identify the number of clusters formed and draw inferences.
#
# Data Description:
# Murder -- Muder rates in different places of United States
# Assualt- Assualt rate in different places of United States
# UrbanPop - urban population in different places of United States
# Rape - Rape rate in different places of United States

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
header_name=['Country','Murder','Assault','UrbanPop','Rape']
cd= pd.read_csv("crime_data.csv",header=None,skiprows=[0],names= header_name) 
cd
# Out:
#            Country  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
cd.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
cd.shape
# Out:
# (50, 5)

# %%
cd.isna().sum()
# Out:
# Country     0
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
cd1=cd.iloc[:,1:5]
cd1.head(5)
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
scaler = StandardScaler()
cd_scal = scaler.fit_transform(cd1)
cd_scal
# Out:
# array([[ 1.25517927,  0.79078716, -0.52619514, -0.00345116],
#        [ 0.51301858,  1.11805959, -1.22406668,  2.50942392],
#        [ 0.07236067,  1.49381682,  1.00912225,  1.05346626],
#        [ 0.23470832,  0.23321191, -1.08449238, -0.18679398],
#        [ 0.28109336,  1.2756352 ,  1.77678094,  2.08881393],
#        [ 0.02597562,  0.40290872,  0.86954794,  1.88390137],
#        [-1.04088037, -0.73648418,  0.79976079, -1.09272319],
#        [-0.43787481,  0.81502956,  0.45082502, -0.58583422],
#        [ 1.76541475,  1.99078607,  1.00912225,  1.1505301 ],
#        [ 2.22926518,  0.48775713, -0.38662083,  0.49265293],
#        [-0.57702994, -1.51224105,  1.21848371, -0.11129987],
#        [-1.20322802, -0.61527217, -0.80534376, -0.75839217],
#        [ 0.60578867,  0.94836277,  1.21848371,  0.29852525],
#        [-0.13637203, -0.70012057, -0.03768506, -0.0250209 ],
#        [-1.29599811, -1.39102904, -0.5959823 , -1.07115345],
# ...

# %%
plt.figure(figsize=(18,9))
plt.title('Crime Data Dindograms')
den = shc.dendrogram(shc.linkage(cd_scal,method= 'ward'))
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.title('Crime Data Dindograms')
den = shc.dendrogram(shc.linkage(cd_scal,method= 'single'))
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.title('Crime Data Dindograms')
den = shc.dendrogram(shc.linkage(cd_scal,method= 'average'))
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.title('Crime Data Dindograms')
den = shc.dendrogram(shc.linkage(cd_scal,method= 'complete'))
plt.show()

# %%
her_clu = AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='complete')

# %%
her_clu
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=4)

# %%
pre_y=her_clu.fit_predict(cd_scal)

# %%
pre_y
# Out:
# array([0, 0, 2, 1, 2, 2, 1, 1, 2, 0, 1, 3, 2, 1, 3, 1, 1, 0, 3, 2, 1, 2,
#        1, 0, 1, 3, 3, 2, 3, 1, 2, 2, 0, 3, 1, 1, 1, 1, 1, 0, 3, 0, 2, 1,
#        3, 1, 1, 3, 1, 1], dtype=int64)

# %%
clusters = pd.DataFrame(pre_y,columns=['clusters'])
clusters
# Out:
#     clusters
# 0          0
# 1          0
# 2          2
# 3          1
# 4          2
# 5          2
# 6          1
# 7          1
# 8          2
# 9          0
# 10         1
# 11         3
# 12         2
# 13         1
# 14         3
# 15         1
# 16         1
# 17         0
# 18         3
# 19         2
# 20         1
# 21         2
# 22         1
# 23         0
# 24         1
# 25         3
# 26         3
# 27         2
# 28         3
# 29         1
# 30         2
# 31         2
# 32         0
# 33         3
# 34         1
# 35         1
# 36         1
# 37         1
# 38         1
# 39         0
# 40         3
# 41         0
# 42         2
# 43         1
# 44         3
# 45         1
# 46         1
# 47         3
# 48         1
# 49         1

# %%
cd['clusters']=clusters
cd
# Out:
#            Country  Murder  Assault  UrbanPop  Rape  clusters
# 0          Alabama    13.2      236        58  21.2         0
# 1           Alaska    10.0      263        48  44.5         0
# 2          Arizona     8.1      294        80  31.0         2
# 3         Arkansas     8.8      190        50  19.5         1
# 4       California     9.0      276        91  40.6         2
# 5         Colorado     7.9      204        78  38.7         2
# 6      Connecticut     3.3      110        77  11.1         1
# 7         Delaware     5.9      238        72  15.8         1
# 8          Florida    15.4      335        80  31.9         2
# 9          Georgia    17.4      211        60  25.8         0
# 10          Hawaii     5.3       46        83  20.2         1
# 11           Idaho     2.6      120        54  14.2         3
# 12        Illinois    10.4      249        83  24.0         2
# 13         Indiana     7.2      113        65  21.0         1
# ...

# %%
cd[cd['clusters']==0]
# Out:
#            Country  Murder  Assault  UrbanPop  Rape  clusters
# 0          Alabama    13.2      236        58  21.2         0
# 1           Alaska    10.0      263        48  44.5         0
# 9          Georgia    17.4      211        60  25.8         0
# 17       Louisiana    15.4      249        66  22.2         0
# 23     Mississippi    16.1      259        44  17.1         0
# 32  North Carolina    13.0      337        45  16.1         0
# 39  South Carolina    14.4      279        48  22.5         0
# 41       Tennessee    13.2      188        59  26.9         0

# %%
cd[cd['clusters']==1]
# Out:
#           Country  Murder  Assault  UrbanPop  Rape  clusters
# 3        Arkansas     8.8      190        50  19.5         1
# 6     Connecticut     3.3      110        77  11.1         1
# 7        Delaware     5.9      238        72  15.8         1
# 10         Hawaii     5.3       46        83  20.2         1
# 13        Indiana     7.2      113        65  21.0         1
# 15         Kansas     6.0      115        66  18.0         1
# 16       Kentucky     9.7      109        52  16.3         1
# 20  Massachusetts     4.4      149        85  16.3         1
# 22      Minnesota     2.7       72        66  14.9         1
# 24       Missouri     9.0      178        70  28.2         1
# 29     New Jersey     7.4      159        89  18.8         1
# 34           Ohio     7.3      120        75  21.4         1
# 35       Oklahoma     6.6      151        68  20.0         1
# 36         Oregon     4.9      159        67  29.3         1
# ...

# %%
cd[cd['clusters']==2]
# Out:
#        Country  Murder  Assault  UrbanPop  Rape  clusters
# 2      Arizona     8.1      294        80  31.0         2
# 4   California     9.0      276        91  40.6         2
# 5     Colorado     7.9      204        78  38.7         2
# 8      Florida    15.4      335        80  31.9         2
# 12    Illinois    10.4      249        83  24.0         2
# 19    Maryland    11.3      300        67  27.8         2
# 21    Michigan    12.1      255        74  35.1         2
# 27      Nevada    12.2      252        81  46.0         2
# 30  New Mexico    11.4      285        70  32.1         2
# 31    New York    11.1      254        86  26.1         2
# 42       Texas    12.7      201        80  25.5         2

# %%
cd[cd['clusters']==3]
# Out:
#           Country  Murder  Assault  UrbanPop  Rape  clusters
# 11          Idaho     2.6      120        54  14.2         3
# 14           Iowa     2.2       56        57  11.3         3
# 18          Maine     2.1       83        51   7.8         3
# 25        Montana     6.0      109        53  16.4         3
# 26       Nebraska     4.3      102        62  16.5         3
# 28  New Hampshire     2.1       57        56   9.5         3
# 33   North Dakota     0.8       45        44   7.3         3
# 40   South Dakota     3.8       86        45  12.8         3
# 44        Vermont     2.2       48        32  11.2         3
# 47  West Virginia     5.7       81        39   9.3         3

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(cd['clusters'],cd['Country'],c=her_clu.labels_,s=300,marker='*') 
plt.grid()
plt.show()
